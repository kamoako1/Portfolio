# %% [markdown]
# <a href="https://colab.research.google.com/github/kamoako1/Portfolio/blob/master/Portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ingest

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/kamoako1/Portfolio/master/airlinetruncate.csv")

# %% [markdown]
# EDA

# %%
df.describe()
# Out:
#          Year  Month  DayofMonth  ...    NASDelay  SecurityDelay  LateAircraftDelay
# count   549.0  549.0       549.0  ...  265.000000     265.000000         265.000000
# mean   2008.0    1.0         3.0  ...    6.373585       0.124528          27.132075
# std       0.0    0.0         0.0  ...   21.541364       1.088665          26.556428
# min    2008.0    1.0         3.0  ...    0.000000       0.000000           0.000000
# 25%    2008.0    1.0         3.0  ...    0.000000       0.000000           9.000000
# 50%    2008.0    1.0         3.0  ...    0.000000       0.000000          22.000000
# 75%    2008.0    1.0         3.0  ...    4.000000       0.000000          38.000000
# max    2008.0    1.0         3.0  ...  203.000000      12.000000         246.000000
#
# [8 rows x 24 columns]

# %%
df.head()
# Out:
#    Year  Month  DayofMonth  ...  NASDelay  SecurityDelay  LateAircraftDelay
# 0  2008      1           3  ...       NaN            NaN                NaN
# 1  2008      1           3  ...       NaN            NaN                NaN
# 2  2008      1           3  ...       NaN            NaN                NaN
# 3  2008      1           3  ...       NaN            NaN                NaN
# 4  2008      1           3  ...       0.0            0.0               32.0
#
# [5 rows x 29 columns]

# %% [markdown]
# Model

# %%
import seaborn as sns
sns.lmplot(x="ArrTime",y="CRSDepTime",data=df)

# %% [markdown]
# Conclusion
